# %% [markdown]
# PROJECT 7: Fitness Data Analysis

# %% [markdown]
# Loading the data into the n.book

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("C:/Users/HPPC/Desktop/Data Science build up day/Apple-Fitness-Data.csv")
data.head(10)
# Out:
#          Date       Time  Step Count  Distance  Energy Burned  \
# 0  2023-03-21  16:01:23           46   0.02543         14.620
# 1  2023-03-21  16:18:37          645   0.40041         14.722
# 2  2023-03-21  16:31:38           14   0.00996         14.603
# 3  2023-03-21  16:45:37           13   0.00901         14.811
# 4  2023-03-21  17:10:30           17   0.00904         15.153
# 5  2023-03-21  18:14:45            8   0.00560         14.958
# 6  2023-03-21  19:02:31          564   0.36089         13.709
# 7  2023-03-21  19:10:51          153   0.09493         14.860
# 8  2023-03-21  19:20:57           16   0.01074         16.804
# 9  2023-03-21  21:04:23           22   0.01526         14.564
#
#    Flights Climbed  Walking Double Support Percentage  Walking Speed
# 0                3                              0.304          3.060
# 1                3                              0.309          3.852
# 2                4                              0.278          3.996
# 3                3                              0.278          5.040
# 4                3                              0.281          5.184
# 5                3                              0.301          5.040
# 6                3                              0.289          4.464
# 7                3                              0.307          4.788
# 8                3                              0.314          4.068
# 9                3                              0.293          3.816

# %%
data.describe()
# Out:
#         Step Count    Distance  Energy Burned  Flights Climbed  \
# count   149.000000  149.000000     149.000000       149.000000
# mean    224.959732    0.147963      14.497933         2.463087
# std     277.919390    0.181177       9.607919         1.570520
# min       1.000000    0.000460       0.171000         1.000000
# 25%      22.000000    0.014020      12.621000         1.000000
# 50%      89.000000    0.062900      14.422000         3.000000
# 75%     365.000000    0.219000      15.441000         3.000000
# max    1082.000000    0.701180      60.514000        13.000000
#
#        Walking Double Support Percentage  Walking Speed
# count                         149.000000     149.000000
# mean                            0.298470       3.973772
# std                             0.022408       1.049368
# min                             0.261000       1.548000
# 25%                             0.279000       3.312000
# 50%                             0.295000       4.140000
# 75%                             0.317000       4.896000
# max                             0.354000       5.580000

# %%
data.isnull().sum()
# Out:
# Date                                 0
# Time                                 0
# Step Count                           0
# Distance                             0
# Energy Burned                        0
# Flights Climbed                      0
# Walking Double Support Percentage    0
# Walking Speed                        0
# dtype: int64

# %%
Fitness_data = pd.DataFrame(data)
Fitness_data.head()
# Out:
#          Date       Time  Step Count  Distance  Energy Burned  \
# 0  2023-03-21  16:01:23           46   0.02543         14.620
# 1  2023-03-21  16:18:37          645   0.40041         14.722
# 2  2023-03-21  16:31:38           14   0.00996         14.603
# 3  2023-03-21  16:45:37           13   0.00901         14.811
# 4  2023-03-21  17:10:30           17   0.00904         15.153
#
#    Flights Climbed  Walking Double Support Percentage  Walking Speed
# 0                3                              0.304          3.060
# 1                3                              0.309          3.852
# 2                4                              0.278          3.996
# 3                3                              0.278          5.040
# 4                3                              0.281          5.184

# %% [markdown]
# EDA PER DATA COLUMN IN RELATION TO TIME
#
# QUESTIONS ARE HIGHLIGHTED IN THE MARKDOWNS BUT THE EXPLANATION RESIDES IN THE README FILE IN MY GITHUB ACC.

# %% [markdown]
# QUESTION 1: WHAT IS THE STEP COUNT OVER TIME?

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = 'Time', y = 'Step Count', data = Fitness_data, markers = True, dashes = False)
plt.xlabel('Time')
plt.ylabel('Steps Takes')
plt.title("Steps taken over Dutation")
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Question 2: What is the Distance covered over the duration

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = 'Time', y = 'Distance', data = Fitness_data, markers = True, dashes = False, color = 'green')
plt.xlabel('Time')
plt.ylabel('Distance Covered')
plt.title("Distance covered in the Dutation")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Question 3: What is the Energy burned over time?

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x = 'Time', y = 'Energy Burned', data = Fitness_data, markers = True, dashes = False, color = 'purple')
plt.xlabel('Time')
plt.ylabel('Enery burned(cal)')
plt.title("Energy burned over the entire Duration")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Question 4: What is the total energy burned in each day?

# %%
plt.figure(figsize=(20,10))
sns.barplot(x = 'Date', y = 'Energy Burned', data = Fitness_data, palette = 'dark')
plt.xlabel('Time')
plt.ylabel('Energy burned (cal)')
plt.title("Energy Burned per day")
plt.xticks(rotation = 90)
plt.show
# Out:
# C:\Users\HPPC\AppData\Local\Temp\ipykernel_6336\2227752517.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Date', y = 'Energy Burned', data = Fitness_data, palette = 'dark')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Question 5: What is the average steps taken per day

# %%
average_steps_taken = Fitness_data.groupby('Date')['Step Count'].mean().reset_index()
average_steps_taken[0:5]

plt.figure(figsize = (15, 8))
sns.barplot(x = 'Date', y = 'Step Count', data = average_steps_taken, palette = 'colorblind')
plt.xlabel('Dates')
plt.ylabel('Steps Taken each day')
plt.title('Average steps taken per day')
plt.show()
# Out:
# C:\Users\HPPC\AppData\Local\Temp\ipykernel_6336\3967608859.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Date', y = 'Step Count', data = average_steps_taken, palette = 'colorblind')

# %% [markdown]
# Question 6:What is the average Distance covered per day

# %%
average_Distance_taken = Fitness_data.groupby('Date')['Distance'].mean().reset_index()
average_Distance_taken[0:5]

plt.figure(figsize = (15, 8))
sns.barplot(x = 'Date', y = 'Distance', data = average_Distance_taken, palette = 'colorblind')
plt.xlabel('Dates')
plt.ylabel('Distance covered Each day')
plt.title('Distance covered per day')
plt.show()
# Out:
# C:\Users\HPPC\AppData\Local\Temp\ipykernel_6336\3145191678.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Date', y = 'Distance', data = average_Distance_taken, palette = 'colorblind')

# %% [markdown]
# Question 7: What is the walking efficiency over time

# %%
Fitness_data['Walking Efficiency'] = Fitness_data['Step Count']/ Fitness_data['Distance']
Fitness_data[0:5]

plt.figure(figsize = (10,10))
sns.lineplot(x = 'Time', y = 'Walking Efficiency', data = Fitness_data, color = 'pink')
plt.xlabel('Time')
plt.ylabel('Walking efficiency')
plt.title('Walking efficiency over time')
plt.xticks(rotation = 90)
plt.show()

# %%
time_intervals = pd.cut(pd.to_datetime(Fitness_data['Time']).dt.hour,
                        bins = [0,12,18,24],
                        labels = ["Morning", "Afternoon", "Evening"],
                        right = False)
                        #this is how you comvert and set the visualization parameters in place when converting a tiimestamp to an interval 


Fitness_data["Time Interval"] = time_intervals
Fitness_data


Fitness_data[0:5]
plt.figure(figsize = (20, 10))
sns.scatterplot(x = 'Step Count', y = 'Walking Speed',data = Fitness_data,hue = 'Time intervals', palette = 'colorblind')
plt.xlabel("Steps taken")
plt.ylabel("Walking speed")
plt.title("Distribution of the steps count and walking speed based on time interval")
plt.colorbar(label = 'time_intervals')
plt.show()
# Out:
# C:\Users\HPPC\AppData\Local\Temp\ipykernel_6336\3008772769.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   time_intervals = pd.cut(pd.to_datetime(Fitness_data['Time']).dt.hour,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 14
#      12 Fitness_data[0:5]
#      13 plt.figure(figsize = (20, 10))
# ---> 14 sns.scatterplot(x = 'Step Count', y = 'Walking Speed',data = Fitness_data,hue = 'Time intervals', palette = 'colorblind')
#      15 plt.xlabel("Steps taken")
#      16 plt.ylabel("Walking speed")
#
# File c:\Program Files\Python312\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File c:\Program Files\Python312\Lib\site-packages\seaborn\relational.py:396, in _ScatterPlotter.__init__(self, data, variables, legend)
#     387 def __init__(self, *, data=None, variables={}, legend=None):
#     388
#     389     # TODO this is messy, we want the mapping to be agnostic about
#     390     # the kind of plot to draw, but for the time being we need to set
#     391     # this information so the SizeMapping can use it
#     392     self._default_size_range = (
#     393         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     394     )
# --> 396     super().__init__(data=data, variables=variables)
#     398     self.legend = legend
#
# File c:\Program Files\Python312\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Program Files\Python312\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Program Files\Python312\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File c:\Program Files\Python312\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `Time intervals` for `hue`. An entry with this name does not appear in `data`.
